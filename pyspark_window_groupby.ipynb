# %% [markdown]
# <a href="https://colab.research.google.com/github/abhayjr11/PysparkPractice_ground/blob/main/pyspark_window_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = [
    (1, "India", "New Delhi", "Asia", "IN", "IND", 1430.0, 3287263, 1947, "Hindi", "INR", "🇮🇳", "india.png", True, "Left", ".in", "+91"),
    (2, "United States", "Washington D.C.", "North America", "US", "USA", 339.0, 9833517, 1776, "English", "USD", "🇺🇸", "usa.png", True, "Right", ".us", "+1"),
    (3, "Canada", "Ottawa", "North America", "CA", "CAN", 40.0, 9984670, 1867, "English/French", "CAD", "🇨🇦", "canada.png", True, "Right", ".ca", "+1"),
    (4, "Mexico", "Mexico City", "North America", "MX", "MEX", 129.0, 1964375, 1810, "Spanish", "MXN", "🇲🇽", "mexico.png", True, "Right", ".mx", "+52"),
    (5, "Brazil", "Brasília", "South America", "BR", "BRA", 215.0, 8515767, 1822, "Portuguese", "BRL", "🇧🇷", "brazil.png", True, "Right", ".br", "+55"),
    (6, "Argentina", "Buenos Aires", "South America", "AR", "ARG", 46.0, 2780400, 1816, "Spanish", "ARS", "🇦🇷", "argentina.png", True, "Right", ".ar", "+54"),
    (7, "United Kingdom", "London", "Europe", "GB", "GBR", 68.0, 243610, 1707, "English", "GBP", "🇬🇧", "uk.png", True, "Left", ".uk", "+44"),
    (8, "France", "Paris", "Europe", "FR", "FRA", 65.0, 551695, 1792, "French", "EUR", "🇫🇷", "france.png", True, "Right", ".fr", "+33"),
    (9, "Germany", "Berlin", "Europe", "DE", "DEU", 84.0, 357022, 1871, "German", "EUR", "🇩🇪", "germany.png", True, "Right", ".de", "+49"),
    (10, "Italy", "Rome", "Europe", "IT", "ITA", 59.0, 301340, 1861, "Italian", "EUR", "🇮🇹", "italy.png", True, "Right", ".it", "+39"),
    (11, "Spain", "Madrid", "Europe", "ES", "ESP", 48.0, 505990, 1492, "Spanish", "EUR", "🇪🇸", "spain.png", True, "Right", ".es", "+34"),
    (12, "Portugal", "Lisbon", "Europe", "PT", "PRT", 10.0, 92212, 1143, "Portuguese", "EUR", "🇵🇹", "portugal.png", True, "Right", ".pt", "+351"),
    (13, "Russia", "Moscow", "Europe/Asia", "RU", "RUS", 144.0, 17098246, 1991, "Russian", "RUB", "🇷🇺", "russia.png", True, "Right", ".ru", "+7"),
    (14, "China", "Beijing", "Asia", "CN", "CHN", 1410.0, 9596961, 1949, "Mandarin", "CNY", "🇨🇳", "china.png", True, "Right", ".cn", "+86"),
    (15, "Japan", "Tokyo", "Asia", "JP", "JPN", 123.0, 377975, 660, "Japanese", "JPY", "🇯🇵", "japan.png", True, "Left", ".jp", "+81"),
    (16, "South Korea", "Seoul", "Asia", "KR", "KOR", 52.0, 100210, 1948, "Korean", "KRW", "🇰🇷", "korea.png", True, "Right", ".kr", "+82"),
    (17, "Indonesia", "Jakarta", "Asia", "ID", "IDN", 278.0, 1904569, 1945, "Indonesian", "IDR", "🇮🇩", "indonesia.png", True, "Left", ".id", "+62"),
    (18, "Malaysia", "Kuala Lumpur", "Asia", "MY", "MYS", 35.0, 330803, 1957, "Malay", "MYR", "🇲🇾", "malaysia.png", True, "Left", ".my", "+60"),
    (19, "Singapore", "Singapore", "Asia", "SG", "SGP", 6.0, 728, 1965, "English", "SGD", "🇸🇬", "singapore.png", True, "Left", ".sg", "+65"),
    (20, "Thailand", "Bangkok", "Asia", "TH", "THA", 71.0, 513120, 1238, "Thai", "THB", "🇹🇭", "thailand.png", True, "Left", ".th", "+66"),
    (21, "Vietnam", "Hanoi", "Asia", "VN", "VNM", 101.0, 331212, 1945, "Vietnamese", "VND", "🇻🇳", "vietnam.png", True, "Right", ".vn", "+84"),
    (22, "Australia", "Canberra", "Oceania", "AU", "AUS", 27.0, 7692024, 1901, "English", "AUD", "🇦🇺", "australia.png", True, "Left", ".au", "+61"),
    (23, "New Zealand", "Wellington", "Oceania", "NZ", "NZL", 5.3, 268838, 1907, "English", "NZD", "🇳🇿", "newzealand.png", True, "Left", ".nz", "+64"),
    (24, "South Africa", "Pretoria", "Africa", "ZA", "ZAF", 62.0, 1221037, 1910, "11 Official Languages", "ZAR", "🇿🇦", "southafrica.png", True, "Left", ".za", "+27"),
    (25, "Nigeria", "Abuja", "Africa", "NG", "NGA", 223.0, 923768, 1960, "English", "NGN", "🇳🇬", "nigeria.png", True, "Right", ".ng", "+234"),
    (26, "Egypt", "Cairo", "Africa", "EG", "EGY", 112.0, 1002450, 1922, "Arabic", "EGP", "🇪🇬", "egypt.png", True, "Right", ".eg", "+20"),
    (27, "Kenya", "Nairobi", "Africa", "KE", "KEN", 55.0, 580367, 1963, "Swahili/English", "KES", "🇰🇪", "kenya.png", True, "Left", ".ke", "+254"),
    (28, "Saudi Arabia", "Riyadh", "Asia", "SA", "SAU", 37.0, 2149690, 1932, "Arabic", "SAR", "🇸🇦", "saudi.png", True, "Right", ".sa", "+966"),
    (29, "United Arab Emirates", "Abu Dhabi", "Asia", "AE", "ARE", 10.0, 83600, 1971, "Arabic", "AED", "🇦🇪", "uae.png", True, "Right", ".ae", "+971"),
    (30, "Turkey", "Ankara", "Europe/Asia", "TR", "TUR", 86.0, 783356, 1923, "Turkish", "TRY", "🇹🇷", "turkey.png", True, "Right", ".tr", "+90"),
    (31, "Pakistan", "Islamabad", "Asia", "PK", "PAK", 241.0, 881913, 1947, "Urdu", "PKR", "🇵🇰", "pakistan.png", True, "Left", ".pk", "+92"),
    (32, "Bangladesh", "Dhaka", "Asia", "BD", "BGD", 173.0, 148460, 1971, "Bengali", "BDT", "🇧🇩", "bangladesh.png", True, "Left", ".bd", "+880"),
    (33, "Nepal", "Kathmandu", "Asia", "NP", "NPL", 31.0, 147516, 1768, "Nepali", "NPR", "🇳🇵", "nepal.png", True, "Left", ".np", "+977"),
    (34, "Sri Lanka", "Sri Jayawardenepura Kotte", "Asia", "LK", "LKA", 22.0, 65610, 1948, "Sinhala/Tamil", "LKR", "🇱🇰", "srilanka.png", True, "Left", ".lk", "+94"),
    (35, "Bhutan", "Thimphu", "Asia", "BT", "BTN", 0.8, 38394, 1907, "Dzongkha", "BTN", "🇧🇹", "bhutan.png", True, "Left", ".bt", "+975"),
    (36, "Maldives", "Malé", "Asia", "MV", "MDV", 0.6, 300, 1965, "Dhivehi", "MVR", "🇲🇻", "maldives.png", True, "Left", ".mv", "+960"),
    (37, "Afghanistan", "Kabul", "Asia", "AF", "AFG", 42.0, 652230, 1919, "Pashto/Dari", "AFN", "🇦🇫", "afghanistan.png", True, "Right", ".af", "+93"),
    (38, "Iran", "Tehran", "Asia", "IR", "IRN", 89.0, 1648195, 1979, "Persian", "IRR", "🇮🇷", "iran.png", True, "Right", ".ir", "+98"),
    (39, "Iraq", "Baghdad", "Asia", "IQ", "IRQ", 45.0, 438317, 1932, "Arabic", "IQD", "🇮🇶", "iraq.png", True, "Right", ".iq", "+964"),
    (40, "Israel", "Jerusalem", "Asia", "IL", "ISR", 10.0, 22072, 1948, "Hebrew", "ILS", "🇮🇱", "israel.png", True, "Right", ".il", "+972"),
    (41, "Belgium", "Brussels", "Europe", "BE", "BEL", 12.0, 30528, 1830, "Dutch/French/German", "EUR", "🇧🇪", "belgium.png", True, "Right", ".be", "+32"),
    (42, "Netherlands", "Amsterdam", "Europe", "NL", "NLD", 18.0, 41543, 1581, "Dutch", "EUR", "🇳🇱", "netherlands.png", True, "Right", ".nl", "+31"),
    (43, "Switzerland", "Bern", "Europe", "CH", "CHE", 9.0, 41285, 1291, "German/French/Italian", "CHF", "🇨🇭", "switzerland.png", True, "Right", ".ch", "+41"),
    (44, "Austria", "Vienna", "Europe", "AT", "AUT", 9.2, 83879, 1955, "German", "EUR", "🇦🇹", "austria.png", True, "Right", ".at", "+43"),
    (45, "Poland", "Warsaw", "Europe", "PL", "POL", 38.0, 312696, 1918, "Polish", "PLN", "🇵🇱", "poland.png", True, "Right", ".pl", "+48"),
    (46, "Ukraine", "Kyiv", "Europe", "UA", "UKR", 37.0, 603628, 1991, "Ukrainian", "UAH", "🇺🇦", "ukraine.png", True, "Right", ".ua", "+380"),
    (47, "Norway", "Oslo", "Europe", "NO", "NOR", 5.5, 385207, 1905, "Norwegian", "NOK", "🇳🇴", "norway.png", True, "Right", ".no", "+47"),
    (48, "Sweden", "Stockholm", "Europe", "SE", "SWE", 10.6, 450295, 1523, "Swedish", "SEK", "🇸🇪", "sweden.png", True, "Right", ".se", "+46"),
    (49, "Finland", "Helsinki", "Europe", "FI", "FIN", 5.6, 338455, 1917, "Finnish", "EUR", "🇫🇮", "finland.png", True, "Right", ".fi", "+358"),
    (50, "Denmark", "Copenhagen", "Europe", "DK", "DNK", 6.0, 42933, 1849, "Danish", "DKK", "🇩🇰", "denmark.png", True, "Right", ".dk", "+45"),
    (51, "Chile", "Santiago", "South America", "CL", "CHL", 20.0, 756102, 1818, "Spanish", "CLP", "🇨🇱", "chile.png", True, "Right", ".cl", "+56"),
    (52, "Peru", "Lima", "South America", "PE", "PER", 34.0, 1285216, 1821, "Spanish", "PEN", "🇵🇪", "peru.png", True, "Right", ".pe", "+51"),
    (53, "Colombia", "Bogotá", "South America", "CO", "COL", 53.0, 1141748, 1810, "Spanish", "COP", "🇨🇴", "colombia.png", True, "Right", ".co", "+57"),
    (54, "Venezuela", "Caracas", "South America", "VE", "VEN", 29.0, 916445, 1811, "Spanish", "VES", "🇻🇪", "venezuela.png", True, "Right", ".ve", "+58"),
    (55, "Ecuador", "Quito", "South America", "EC", "ECU", 18.0, 283561, 1830, "Spanish", "USD", "🇪🇨", "ecuador.png", True, "Right", ".ec", "+593"),
    (56, "Uruguay", "Montevideo", "South America", "UY", "URY", 3.5, 176215, 1828, "Spanish", "UYU", "🇺🇾", "uruguay.png", True, "Right", ".uy", "+598"),
    (57, "Paraguay", "Asunción", "South America", "PY", "PRY", 7.0, 406752, 1811, "Spanish", "PYG", "🇵🇾", "paraguay.png", True, "Right", ".py", "+595"),
    (58, "Bolivia", "Sucre", "South America", "BO", "BOL", 12.0, 1098581, 1825, "Spanish", "BOB", "🇧🇴", "bolivia.png", True, "Right", ".bo", "+591"),
    (59, "Morocco", "Rabat", "Africa", "MA", "MAR", 38.0, 446550, 1956, "Arabic", "MAD", "🇲🇦", "morocco.png", True, "Right", ".ma", "+212"),
    (60, "Algeria", "Algiers", "Africa", "DZ", "DZA", 46.0, 2381741, 1962, "Arabic", "DZD", "🇩🇿", "algeria.png", True, "Right", ".dz", "+213"),
    (61, "Tunisia", "Tunis", "Africa", "TN", "TUN", 12.5, 163610, 1956, "Arabic", "TND", "🇹🇳", "tunisia.png", True, "Right", ".tn", "+216"),
    (62, "Ethiopia", "Addis Ababa", "Africa", "ET", "ETH", 128.0, 1104300, 1941, "Amharic", "ETB", "🇪🇹", "ethiopia.png", True, "Right", ".et", "+251"),
    (63, "Ghana", "Accra", "Africa", "GH", "GHA", 34.0, 238535, 1957, "English", "GHS", "🇬🇭", "ghana.png", True, "Right", ".gh", "+233"),
    (64, "Uganda", "Kampala", "Africa", "UG", "UGA", 50.0, 241038, 1962, "English", "UGX", "🇺🇬", "uganda.png", True, "Left", ".ug", "+256"),
    (65, "Tanzania", "Dodoma", "Africa", "TZ", "TZA", 68.0, 947303, 1961, "Swahili", "TZS", "🇹🇿", "tanzania.png", True, "Left", ".tz", "+255"),
    (66, "Zimbabwe", "Harare", "Africa", "ZW", "ZWE", 17.0, 390757, 1980, "English", "ZWL", "🇿🇼", "zimbabwe.png", True, "Left", ".zw", "+263"),
    (67, "Fiji", "Suva", "Oceania", "FJ", "FJI", 0.9, 18274, 1970, "English", "FJD", "🇫🇯", "fiji.png", True, "Left", ".fj", "+679"),
    (68, "Papua New Guinea", "Port Moresby", "Oceania", "PG", "PNG", 10.0, 462840, 1975, "English", "PGK", "🇵🇬", "papua_new_guinea.png", True, "Left", ".pg", "+675"),
    (69, "Samoa", "Apia", "Oceania", "WS", "WSM", 0.2, 2842, 1962, "Samoan", "WST", "🇼🇸", "samoa.png", True, "Left", ".ws", "+685"),
    (70, "Tonga", "Nukuʻalofa", "Oceania", "TO", "TON", 0.1, 747, 1970, "Tongan", "TOP", "🇹🇴", "tonga.png", True, "Left", ".to", "+676"),
]

columns = [
    "country_id",
    "country",
    "capital",
    "continent",
    "iso2",
    "iso3",
    "population_million",
    "area_sq_km",
    "independence_year",
    "official_language",
    "currency",
    "flag_emoji",
    "flag_image",
    "is_un_member",
    "drives_on",
    "internet_domain",
    "phone_code"
]
fpath = "C:/Users/HP/Documents/data/country_30-07-2026.csv"

# %%
flag_data = [
    (
        "country_30-07-2026.csv",      # file_name
        70,                             #record_count
        "30-07-2026",                    # file_date
        [
            "country_id",
            "country",
            "capital",
            "continent",
            "iso2",
            "iso3",
            "population_million",
            "area_sq_km",
            "independence_year",
            "official_language",
            "currency",
            "flag_emoji",
            "flag_image",
            "is_un_member",
            "drives_on",
            "internet_domain",
            "phone_code"
        ]                              # schema
    )
]

flag_columns = [
    "file_name",
    "record_count",
    "file_date",
    "schema"
]

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window
from pyspark.sql.types import DateType
from datetime import datetime


spark = SparkSession.builder.enableHiveSupport().getOrCreate()


cdf = spark.createDataFrame(data, columns)
fdf = spark.createDataFrame(flag_data,flag_columns)

# %%
# validation starts
fpath = "C:/Users/HP/Documents/data/country_30-07-2026.csv"

#file_name check
fname = fpath.split('/')[-1]
w=x=y=z= 0
w = (1 if fname == fdf.select('file_name').first()[0] else 0)
x = (1 if cdf.count() == fdf.select('record_count').first()[0] else 0)
fdate = fname.split('.')[0].split('_')[1]
fdate = datetime.strptime(fdate,"%d-%m-%Y").date()
flag_date = datetime.strptime(fdf.select('file_date').first()[0],"%d-%m-%Y").date()
y = ( 1 if fdate == flag_date else 0 )
fschema = cdf.columns
z = (1 if fschema == fdf.select('schema').first()[0] else 0)
if w+x+y+z ==4:
  print("---------------Validation completed---------------")
else:
  print("---------------validdation failed---------------")
# Out:
# ---------------Validation completed---------------

# %%
# load data into raw tabel

#add two colmmnus 1: ingetion_dt_tm 2: datetime

cdf=cdf.withColumn('datetime', lit(fdate))
cdf=cdf.withColumn('ingetion_dt_tm', lit(current_timestamp()))
cdf.write.mode('overwrite').saveAsTable("country_date_tbl")

spark.sql("select * from country_date_tbl where country = 'India'").show()
# Out:
# +----------+-------+---------+---------+----+----+------------------+----------+-----------------+-----------------+--------+----------+----------+------------+---------+---------------+----------+----------+--------------------+
# |country_id|country|  capital|continent|iso2|iso3|population_million|area_sq_km|independence_year|official_language|currency|flag_emoji|flag_image|is_un_member|drives_on|internet_domain|phone_code|  datetime|      ingetion_dt_tm|
# +----------+-------+---------+---------+----+----+------------------+----------+-----------------+-----------------+--------+----------+----------+------------+---------+---------------+----------+----------+--------------------+
# |         1|  India|New Delhi|     Asia|  IN| IND|            1430.0|   3287263|             1947|            Hindi|     INR|      🇮🇳| india.png|        true|     Left|            .in|       +91|2026-07-30|2026-07-30 17:22:...|
# ...

# %%
# 1. Find the country with the highest population in each continent.
win = Window.partitionBy('continent').orderBy(desc('population_million'))
cdf.withColumn('rank',row_number().over(win)).filter(col('rank')==1).select('country','continent','population_million').show()

# 2. Find the top 2 largest countries (by area) in every continent.
win = Window.partitionBy('continent').orderBy(desc('area_sq_km'))
cdf.withColumn('rank',row_number().over(win)).filter(col('rank')<=2).select('country','continent','area_sq_km').show()

# 3. Rank countries by population within each continent.
win = Window.partitionBy('continent').orderBy(desc('population_million'))
cdf.withColumn('rank',row_number().over(win)).select('country','continent','rank').show(1)
# 6. Find countries whose population is greater than the average population of their continent.

# 7. Find countries whose area is smaller than the average area of their continent.
# Out:
# +-------------+-------------+------------------+
# |      country|    continent|population_million|
# +-------------+-------------+------------------+
# |      Nigeria|       Africa|             223.0|
# |        India|         Asia|            1430.0|
# |      Germany|       Europe|              84.0|
# |       Russia|  Europe/Asia|             144.0|
# |United States|North America|             339.0|
# |    Australia|      Oceania|              27.0|
# |       Brazil|South America|             215.0|
# +-------------+-------------+------------------+
#
# +----------------+-------------+----------+
# |         country|    continent|area_sq_km|
# +----------------+-------------+----------+
# |         Algeria|       Africa|   2381741|
# |    South Africa|       Africa|   1221037|
# |           China|         Asia|   9596961|
# |           India|         Asia|   3287263|
# |         Ukraine|       Europe|    603628|
# |          France|       Europe|    551695|
# ...
